# %% [markdown]
# <a href="https://colab.research.google.com/github/BraidoLuis/estudos-yolo/blob/main/Estudos_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **DETECÇÃO**
#
# ---

# %%
from ultralytics import YOLO

model = YOLO("yolo26n.pt")

# %%
results = model('/content/Amor.jpeg', save=True)
# Out:
# image 1/1 /content/person.jpg: 448x640 19 persons, 17.0ms
# Speed: 3.4ms preprocess, 17.0ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/pose/predict
# 2 labels saved to /content/runs/pose/predict/labels

# %%
for result in results:
  boxes = result.boxes
  result.save(filename='result_2.jpg')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = '/content/result.jpg'

image = mpimg.imread(img)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# **Segmentação**
#
#
# ---

# %%
from ultralytics import YOLO

model = YOLO("yolo26n-seg.pt")

# %%
results = model('/content/Amor.jpeg', save=True, save_txt=True, save_conf=True)
# Out:
# image 1/1 /content/Amor.jpeg: 640x480 2 persons, 24.2ms
# Speed: 2.4ms preprocess, 24.2ms inference, 15.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/segment/predict
# 1 label saved to /content/runs/segment/predict/labels

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = '/content/runs/segment/predict/Amor.jpg'

image = mpimg.imread(img)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# **CLASSIFICAÇÃO**
#
# ---

# %%
from ultralytics import YOLO

model = YOLO("yolo26n-cls.pt")

# %%
results = model('/content/Amor.jpeg', save=True, save_txt=True, save_conf=True)
# Out:
# ...
# image 1/1 /content/Amor.jpeg: 224x224 sandbar 0.23, maillot_(tank_suit) 0.22, maillot_(tights) 0.21, sunscreen 0.13, snorkel 0.06, 5.2ms
# Speed: 31.1ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict
# 1 label saved to /content/runs/classify/predict/labels

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = '/content/runs/classify/predict/Amor.jpg'

image = mpimg.imread(img)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# **POSE**
#
# ---

# %%
from ultralytics import YOLO

model = YOLO("yolo26n-pose.pt")

# %%
results = model('/content/person.jpg', save=True)
# Out:
# image 1/1 /content/person.jpg: 448x640 19 persons, 90.8ms
# Speed: 2.8ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/pose/predict
# 2 labels saved to /content/runs/pose/predict/labels

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = '/content/runs/pose/predict/Amor.jpg'

image = mpimg.imread(img)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# **TRACKER**
#
# ---

# %%
from ultralytics  import YOLO

model_detect = YOLO("yolo26n.pt")
model_segment = YOLO("yolo26n-seg.pt")
model_keypoints = YOLO("yolo26n-pose.pt")

# %%
results = model_segment.track(source='/content/people.mp4', save=True, tracker="bytetrack.yaml")
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/341) /content/people.mp4: 384x640 13 persons, 15.4ms
# video 1/1 (frame 2/341) /content/people.mp4: 384x640 12 persons, 13.3ms
# video 1/1 (frame 3/341) /content/people.mp4: 384x640 14 persons, 18.2ms
# video 1/1 (frame 4/341) /content/people.mp4: 384x640 14 persons, 14.3ms
# video 1/1 (frame 5/341) /content/people.mp4: 384x640 13 persons, 13.6ms
# ...

# %% [markdown]
# **Caixa delimitadora orientada**
#
# ---

# %%
from ultralytics import YOLO

model = YOLO("yolo26n-obb.pt")

# %%
results = model(source='/content/plane.jpg', save=True, save_txt=True, save_conf=True)
# Out:
# image 1/1 /content/plane.jpg: 736x1024 7 planes, 63.2ms
# Speed: 6.3ms preprocess, 63.2ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1024)
# Results saved to /content/runs/obb/predict
# 1 label saved to /content/runs/obb/predict/labels

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = '/content/runs/obb/predict/plane.jpg'

image = mpimg.imread(img)
plt.imshow(image)
plt.axis('off')
plt.show()
